# %%
from fcis.core import * 
from fcis.accidents import Accidents

# %%
# https://www.osha.gov/pls/imis/AccidentSearch.search
# ?p_logger=1
# &acc_description=boat+Employee
# &acc_Abstract=boat+Employee
# &acc_keyword=water+drown+boat
# &sic=
# &naics=
# &Office=All
# &officetype=All
# &endmonth=06
# &endday=18
# &endyear=2002
# &startmonth=06
# &startday=18
# &startyear=2023
# &InspNr=

# %%
# Accidents Examples
import fcis
desc1= ["boat", "Employee"]
abs1=  ["boat", "Employee"]
keys1 = ["water", "drown", "boat"]
client = fcis.FCIS(descriptions=desc1, abstracts=abs1, keywords=keys1)
# test
# print(client._get_validated_keywords(keys1))
# print(client._load_accidents_search_page())

page = client._load_accidents_search_page()
client._scrape_accidents_search_results(page)

# %%
# Accidents Examples
import fcis
import pprint
desc1= []
keys1 = ['"Quench Tank"']
# keys1 = ['Quench Tank']
client = fcis.FCIS(descriptions=desc1, keywords=keys1)
page = client._load_accidents_search_page()
# page = client._load_accidents_search_page(p_finish=30)
client._scrape_accidents_search_results(page)

# %%
# Accidents Examples
import fcis
import pprint
desc1= ["employee"]
keys1 = ["fire"]
client = fcis.FCIS(descriptions=desc1, keywords=keys1)
page = client._load_accidents_search_page()
# client._scrape_accidents_search_results(page)
client.get_accidents(p_show=100)
# Out:
# https://www.osha.gov/pls/imis/AccidentSearch.search?acc_description=employee&acc_keyword=fire
# https://www.osha.gov/pls/imis/AccidentSearch.search?acc_description=employee&acc_keyword=fire&p_show=100
# [{'accident_id': '141245.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=141245.015',
#   'summary_nr': '141245.01',
#   'event_date': '11/17/2021',
#   'report_id': '0213900',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed After Falling Through Elevator Shaft',
#   'fatility': 'X'},
#  {'accident_id': '141077.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=141077.015',
#   'summary_nr': '141077.01',
#   'event_date': '11/13/2021',
#   'report_id': '0418200',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Electrocuted When Truck Boom Hits Power Lines',
#   'fatility': 'X'},
#  {'accident_id': '141079.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=141079.015',
#   'summary_nr': '141079.01',
#   'event_date': '11/11/2021',
#   'report_id': '0111400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Toluene Flash Fire Explosion',
#   'fatility': 'X'},
#  {'accident_id': '139559.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=139559.015',
#   'summary_nr': '139559.01',
#   'event_date': '09/07/2021',
#   'report_id': '0215000',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies Following Building Fire',
#   'fatility': 'X'},
#  {'accident_id': '140013.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=140013.015',
#   'summary_nr': '140013.01',
#   'event_date': '09/03/2021',
#   'report_id': '1054114',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'One Employee Is Killed, Two Are Injured After Explosion At D',
#   'fatility': 'X'},
#  {'accident_id': '140297.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=140297.015',
#   'summary_nr': '140297.01',
#   'event_date': '08/26/2021',
#   'report_id': '1055360',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Fall From Bridge',
#   'fatility': 'X'},
#  {'accident_id': '138653.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138653.015',
#   'summary_nr': '138653.01',
#   'event_date': '08/25/2021',
#   'report_id': '0452110',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Explosion And Fire',
#   'fatility': 'X'},
#  {'accident_id': '138665.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138665.015',
#   'summary_nr': '138665.01',
#   'event_date': '08/24/2021',
#   'report_id': '0253630',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed When Run Over By Backing Vehicle',
#   'fatility': 'X'},
#  {'accident_id': '138504.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138504.015',
#   'summary_nr': '138504.01',
#   'event_date': '08/23/2021',
#   'report_id': '1054116',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed When Crushed By Tree Fighting Wildfire',
#   'fatility': 'X'},
#  {'accident_id': '138657.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138657.015',
#   'summary_nr': '138657.01',
#   'event_date': '08/18/2021',
#   'report_id': '0454713',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed While Elevating Aerial Lift',
#   'fatility': 'X'},
#  {'accident_id': '138174.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138174.015',
#   'summary_nr': '138174.01',
#   'event_date': '08/16/2021',
#   'report_id': '0950635',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed When Trapped In Fire',
#   'fatility': 'X'},
#  {'accident_id': '138102.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138102.015',
#   'summary_nr': '138102.01',
#   'event_date': '08/11/2021',
#   'report_id': '0352440',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed Fighting House Fire',
#   'fatility': 'X'},
#  {'accident_id': '137896.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=137896.015',
#   'summary_nr': '137896.01',
#   'event_date': '08/05/2021',
#   'report_id': '0950621',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed By Drug Overdose',
#   'fatility': 'X'},
#  {'accident_id': '137943.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=137943.015',
#   'summary_nr': '137943.01',
#   'event_date': '08/05/2021',
#   'report_id': '0552652',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Trapped And Killed In Fire',
#   'fatility': 'X'},
#  {'accident_id': '137279.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=137279.015',
#   'summary_nr': '137279.01',
#   'event_date': '07/16/2021',
#   'report_id': '0950635',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies From Heart Attack While Breaking Concrete With',
#   'fatility': 'X'},
#  {'accident_id': '137361.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=137361.015',
#   'summary_nr': '137361.01',
#   'event_date': '07/16/2021',
#   'report_id': '0627700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed Due To Explosion While Welding',
#   'fatility': 'X'},
#  {'accident_id': '137560.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=137560.015',
#   'summary_nr': '137560.01',
#   'event_date': '07/05/2021',
#   'report_id': '0830500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed From Natural Causes',
#   'fatility': 'X'},
#  {'accident_id': '136856.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=136856.015',
#   'summary_nr': '136856.01',
#   'event_date': '07/01/2021',
#   'report_id': '0355121',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies From Heat Exhaustion',
#   'fatility': 'X'},
#  {'accident_id': '136811.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=136811.015',
#   'summary_nr': '136811.01',
#   'event_date': '06/30/2021',
#   'report_id': '0551800',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned In Fire Pit, Later Dies',
#   'fatility': 'X'},
#  {'accident_id': '136851.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=136851.015',
#   'summary_nr': '136851.01',
#   'event_date': '06/29/2021',
#   'report_id': '0418600',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Electrocuted While Unloading Concrete Debris',
#   'fatility': 'X'},
#  {'accident_id': '137077.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=137077.015',
#   'summary_nr': '137077.01',
#   'event_date': '06/26/2021',
#   'report_id': '0253410',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies During Live Burn Training',
#   'fatility': 'X'},
#  {'accident_id': '138060.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138060.015',
#   'summary_nr': '138060.01',
#   'event_date': '06/02/2021',
#   'report_id': '0627500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed Firefighting After Hard Skydiving Landing',
#   'fatility': 'X'},
#  {'accident_id': '139968.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=139968.015',
#   'summary_nr': '139968.01',
#   'event_date': '05/12/2021',
#   'report_id': '0150900',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed When Scba Runs Out Of Air During Fire',
#   'fatility': 'X'},
#  {'accident_id': '134640.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134640.015',
#   'summary_nr': '134640.01',
#   'event_date': '04/08/2021',
#   'report_id': '0522500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'One Employee Is Killed, Nine Are Injured In Resin Plant Expl',
#   'fatility': 'X'},
#  {'accident_id': '134464.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134464.015',
#   'summary_nr': '134464.01',
#   'event_date': '03/31/2021',
#   'report_id': '0830600',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed After Being Crushed By Fire Truck Cab',
#   'fatility': 'X'},
#  {'accident_id': '134452.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134452.015',
#   'summary_nr': '134452.01',
#   'event_date': '03/31/2021',
#   'report_id': '0355114',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Found Unresponsive, Later Dies Of Heart Attack',
#   'fatility': 'X'},
#  {'accident_id': '134306.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134306.015',
#   'summary_nr': '134306.01',
#   'event_date': '03/23/2021',
#   'report_id': '0253690',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Building Fire And Collapse',
#   'fatility': 'X'},
#  {'accident_id': '135396.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=135396.015',
#   'summary_nr': '135396.01',
#   'event_date': '03/23/2021',
#   'report_id': '1054113',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Dust Explosion',
#   'fatility': 'X'},
#  {'accident_id': '134138.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134138.015',
#   'summary_nr': '134138.01',
#   'event_date': '03/16/2021',
#   'report_id': '0653510',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies After Residual Fluid Fire While Cutting Pipe',
#   'fatility': 'X'},
#  {'accident_id': '134072.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134072.015',
#   'summary_nr': '134072.01',
#   'event_date': '03/15/2021',
#   'report_id': '0830100',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'One Employee Is Killed And Another Incurs Burns After Oil Ta',
#   'fatility': 'X'},
#  {'accident_id': '134449.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134449.015',
#   'summary_nr': '134449.01',
#   'event_date': '03/08/2021',
#   'report_id': '0253410',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Collapses Running Laps, Later Dies',
#   'fatility': 'X'},
#  {'accident_id': '133820.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=133820.015',
#   'summary_nr': '133820.01',
#   'event_date': '03/06/2021',
#   'report_id': '0316700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed After Falling Into Kettle Of Molten Lead',
#   'fatility': 'X'},
#  {'accident_id': '134055.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134055.015',
#   'summary_nr': '134055.01',
#   'event_date': '03/03/2021',
#   'report_id': '0253670',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Heart Attack During Training, Later Dies',
#   'fatility': 'X'},
#  {'accident_id': '133046.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=133046.015',
#   'summary_nr': '133046.01',
#   'event_date': '02/02/2021',
#   'report_id': '0317500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Falls From Fixed Ladder And Is Killed',
#   'fatility': 'X'},
#  {'accident_id': '134538.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134538.015',
#   'summary_nr': '134538.01',
#   'event_date': '01/19/2021',
#   'report_id': '0950611',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Fractures Leg In Fall From Stepladder',
#   'fatility': '\xa0'},
#  {'accident_id': '132457.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=132457.015',
#   'summary_nr': '132457.01',
#   'event_date': '01/14/2021',
#   'report_id': '0521400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Electrocuted When Feed Auger Contacted Live 7,80',
#   'fatility': 'X'},
#  {'accident_id': '132062.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=132062.015',
#   'summary_nr': '132062.01',
#   'event_date': '12/29/2020',
#   'report_id': '0625700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed When Diesel Tank Explodes',
#   'fatility': 'X'},
#  {'accident_id': '131610.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=131610.015',
#   'summary_nr': '131610.01',
#   'event_date': '12/09/2020',
#   'report_id': '0452110',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Semi-Trailer Wreck',
#   'fatility': 'X'},
#  {'accident_id': '131032.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=131032.015',
#   'summary_nr': '131032.01',
#   'event_date': '11/11/2020',
#   'report_id': '0521400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'One Employee Is Killed In Explosion, One Is Injured',
#   'fatility': 'X'},
#  {'accident_id': '130975.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=130975.015',
#   'summary_nr': '130975.01',
#   'event_date': '11/04/2020',
#   'report_id': '0452110',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed While Handling Downed Power Line',
#   'fatility': 'X'},
#  {'accident_id': '130729.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=130729.015',
#   'summary_nr': '130729.01',
#   'event_date': '10/26/2020',
#   'report_id': '0419700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'One Employee Is Killed, Another Is Injured From Fire',
#   'fatility': 'X'},
#  {'accident_id': '131678.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=131678.015',
#   'summary_nr': '131678.01',
#   'event_date': '10/07/2020',
#   'report_id': '0950611',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Fall From Third Floor Fire Escape',
#   'fatility': 'X'},
#  {'accident_id': '129654.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129654.015',
#   'summary_nr': '129654.01',
#   'event_date': '09/17/2020',
#   'report_id': '0936200',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed While Fighting Wildfire',
#   'fatility': 'X'},
#  {'accident_id': '129609.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129609.015',
#   'summary_nr': '129609.01',
#   'event_date': '09/17/2020',
#   'report_id': '0625700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed From Fire And Fall',
#   'fatility': 'X'},
#  {'accident_id': '129180.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129180.015',
#   'summary_nr': '129180.01',
#   'event_date': '09/01/2020',
#   'report_id': '0625400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Front End Loader Fire',
#   'fatility': 'X'},
#  {'accident_id': '129178.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129178.015',
#   'summary_nr': '129178.01',
#   'event_date': '08/31/2020',
#   'report_id': '0950623',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Wildfire',
#   'fatility': 'X'},
#  {'accident_id': '129605.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129605.015',
#   'summary_nr': '129605.01',
#   'event_date': '08/24/2020',
#   'report_id': '1054115',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Traumatic Injury, Dies In Helicopter Crash',
#   'fatility': 'X'},
#  {'accident_id': '130120.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=130120.015',
#   'summary_nr': '130120.01',
#   'event_date': '08/04/2020',
#   'report_id': '0253690',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies Of Cardiac Arrest After Responding To Calls',
#   'fatility': 'X'},
#  {'accident_id': '128287.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=128287.015',
#   'summary_nr': '128287.01',
#   'event_date': '07/30/2020',
#   'report_id': '0626300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Burns By Arc Flash When Installing Jumper',
#   'fatility': '\xa0'},
#  {'accident_id': '128180.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=128180.015',
#   'summary_nr': '128180.01',
#   'event_date': '07/29/2020',
#   'report_id': '0950621',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Heat Illness While Participating In Fire Dri',
#   'fatility': '\xa0'},
#  {'accident_id': '130807.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=130807.015',
#   'summary_nr': '130807.01',
#   'event_date': '07/25/2020',
#   'report_id': '0950624',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Heat-Related Illness During Training Hike',
#   'fatility': '\xa0'},
#  {'accident_id': '132028.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=132028.015',
#   'summary_nr': '132028.01',
#   'event_date': '07/22/2020',
#   'report_id': '0950643',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Heat Exhaustion While On Hike',
#   'fatility': '\xa0'},
#  {'accident_id': '135643.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=135643.015',
#   'summary_nr': '135643.01',
#   'event_date': '07/17/2020',
#   'report_id': '0950633',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Heat Related Injury Fighting Brush Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '128185.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=128185.015',
#   'summary_nr': '128185.01',
#   'event_date': '07/15/2020',
#   'report_id': '0950624',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Injured From Smoke Inhalation And Heat Stress',
#   'fatility': '\xa0'},
#  {'accident_id': '127810.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=127810.015',
#   'summary_nr': '127810.01',
#   'event_date': '07/12/2020',
#   'report_id': '0454716',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned While Blowing Glass',
#   'fatility': '\xa0'},
#  {'accident_id': '128142.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=128142.015',
#   'summary_nr': '128142.01',
#   'event_date': '07/07/2020',
#   'report_id': '0729300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Flash Burns While Pouring Coloring Into Rum',
#   'fatility': '\xa0'},
#  {'accident_id': '128150.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=128150.015',
#   'summary_nr': '128150.01',
#   'event_date': '07/03/2020',
#   'report_id': '0950624',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Becomes Ill During Hike',
#   'fatility': '\xa0'},
#  {'accident_id': '132133.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=132133.015',
#   'summary_nr': '132133.01',
#   'event_date': '07/02/2020',
#   'report_id': '0950615',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Burns While Transferring Fuel',
#   'fatility': '\xa0'},
#  {'accident_id': '127176.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=127176.015',
#   'summary_nr': '127176.01',
#   'event_date': '06/22/2020',
#   'report_id': '0953220',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Using Propane Torch, Catches On Fire And Is Killed',
#   'fatility': 'X'},
#  {'accident_id': '127507.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=127507.015',
#   'summary_nr': '127507.01',
#   'event_date': '06/19/2020',
#   'report_id': '0316300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Fire Incident',
#   'fatility': 'X'},
#  {'accident_id': '130916.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=130916.015',
#   'summary_nr': '130916.01',
#   'event_date': '05/28/2020',
#   'report_id': '0653510',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'One Employee Is Killed And Two Are Injured In Tank Explosion',
#   'fatility': 'X'},
#  {'accident_id': '126122.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=126122.015',
#   'summary_nr': '126122.01',
#   'event_date': '05/13/2020',
#   'report_id': '0215000',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee #1 Is Killed And Employee #2 Incurs Lacerations Fro',
#   'fatility': 'X'},
#  {'accident_id': '125288.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=125288.015',
#   'summary_nr': '125288.01',
#   'event_date': '04/07/2020',
#   'report_id': '0453730',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed By Flash Fire',
#   'fatility': 'X'},
#  {'accident_id': '126350.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=126350.015',
#   'summary_nr': '126350.01',
#   'event_date': '03/27/2020',
#   'report_id': '0253650',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed From Smoke Inhalation From Fire',
#   'fatility': 'X'},
#  {'accident_id': '124895.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=124895.015',
#   'summary_nr': '124895.01',
#   'event_date': '03/18/2020',
#   'report_id': '0950615',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed When Energized While Tree Trimming',
#   'fatility': 'X'},
#  {'accident_id': '124864.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=124864.015',
#   'summary_nr': '124864.01',
#   'event_date': '03/13/2020',
#   'report_id': '0552652',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Falls Through Floor, Is Stuck In Between Joists, An',
#   'fatility': 'X'},
#  {'accident_id': '123677.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=123677.015',
#   'summary_nr': '123677.01',
#   'event_date': '01/29/2020',
#   'report_id': '0625400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Burns From Servicing Oil And Gas Well And L',
#   'fatility': 'X'},
#  {'accident_id': '124219.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=124219.015',
#   'summary_nr': '124219.01',
#   'event_date': '01/21/2020',
#   'report_id': '0352440',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Fractures Back In Fall From Ladder',
#   'fatility': '\xa0'},
#  {'accident_id': '123486.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=123486.015',
#   'summary_nr': '123486.01',
#   'event_date': '01/17/2020',
#   'report_id': '0112300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies Of Cardiac Arrest',
#   'fatility': 'X'},
#  {'accident_id': '126948.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=126948.015',
#   'summary_nr': '126948.01',
#   'event_date': '12/21/2019',
#   'report_id': '0953220',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Attempts To Rescue Residents During Building Fire A',
#   'fatility': 'X'},
#  {'accident_id': '127369.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=127369.015',
#   'summary_nr': '127369.01',
#   'event_date': '12/16/2019',
#   'report_id': '0552652',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Fire',
#   'fatility': 'X'},
#  {'accident_id': '122671.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122671.015',
#   'summary_nr': '122671.01',
#   'event_date': '12/05/2019',
#   'report_id': '0253680',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Responds To Fire Alarm And Is Killed From Heart Att',
#   'fatility': 'X'},
#  {'accident_id': '122161.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122161.015',
#   'summary_nr': '122161.01',
#   'event_date': '11/26/2019',
#   'report_id': '0552652',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught In Flash Fire And Is Killed',
#   'fatility': 'X'},
#  {'accident_id': '124210.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=124210.015',
#   'summary_nr': '124210.01',
#   'event_date': '11/13/2019',
#   'report_id': '0950644',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Trapped In Break Room During Flash Fire And Is K',
#   'fatility': 'X'},
#  {'accident_id': '121458.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=121458.015',
#   'summary_nr': '121458.01',
#   'event_date': '11/05/2019',
#   'report_id': '0950411',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned And Killed In Tanker Truck Explosion',
#   'fatility': 'X'},
#  {'accident_id': '121752.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=121752.015',
#   'summary_nr': '121752.01',
#   'event_date': '11/05/2019',
#   'report_id': '0111400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies In Explosive Reaction',
#   'fatility': 'X'},
#  {'accident_id': '120663.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=120663.015',
#   'summary_nr': '120663.01',
#   'event_date': '09/30/2019',
#   'report_id': '0751910',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Burns From Fire, Later Dies',
#   'fatility': 'X'},
#  {'accident_id': '120052.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=120052.015',
#   'summary_nr': '120052.01',
#   'event_date': '09/20/2019',
#   'report_id': '0215800',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Gasoline Tank Explosion',
#   'fatility': 'X'},
#  {'accident_id': '119910.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119910.015',
#   'summary_nr': '119910.01',
#   'event_date': '09/16/2019',
#   'report_id': '0551800',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Fatal Burns When Caught In Petroleum Fire',
#   'fatility': 'X'},
#  {'accident_id': '119958.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119958.015',
#   'summary_nr': '119958.01',
#   'event_date': '09/13/2019',
#   'report_id': '0418200',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Burns During Malfunction When Tcu Explodes',
#   'fatility': '\xa0'},
#  {'accident_id': '119913.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119913.015',
#   'summary_nr': '119913.01',
#   'event_date': '09/04/2019',
#   'report_id': '0216000',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Gasoline Explosion At Auto Salvage Yar',
#   'fatility': 'X'},
#  {'accident_id': '119651.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119651.015',
#   'summary_nr': '119651.01',
#   'event_date': '09/04/2019',
#   'report_id': '0830500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned When Atmosphere Ignites',
#   'fatility': '\xa0'},
#  {'accident_id': '120228.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=120228.015',
#   'summary_nr': '120228.01',
#   'event_date': '09/01/2019',
#   'report_id': '0936200',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employees Are Caught In Fire On Excursion Boat, One Employee',
#   'fatility': 'X'},
#  {'accident_id': '120682.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=120682.015',
#   'summary_nr': '120682.01',
#   'event_date': '09/01/2019',
#   'report_id': '1055350',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Overcome By Flames From Wildland Fire, Later Die',
#   'fatility': 'X'},
#  {'accident_id': '119327.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119327.015',
#   'summary_nr': '119327.01',
#   'event_date': '08/21/2019',
#   'report_id': '1054111',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Crashes Truck And Trailer Into Roadway Sign And Is',
#   'fatility': 'X'},
#  {'accident_id': '119642.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119642.015',
#   'summary_nr': '119642.01',
#   'event_date': '08/19/2019',
#   'report_id': '0950624',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Second Degree Burns While Fire Fighting',
#   'fatility': '\xa0'},
#  {'accident_id': '123023.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=123023.015',
#   'summary_nr': '123023.01',
#   'event_date': '08/15/2019',
#   'report_id': '1054114',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned After Furnace Explosion',
#   'fatility': '\xa0'},
#  {'accident_id': '118994.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118994.015',
#   'summary_nr': '118994.01',
#   'event_date': '08/13/2019',
#   'report_id': '0950621',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Heat Illness And Cramps After Working Outdo',
#   'fatility': '\xa0'},
#  {'accident_id': '118824.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118824.015',
#   'summary_nr': '118824.01',
#   'event_date': '08/09/2019',
#   'report_id': '0953220',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Fall Through Hole In Floor',
#   'fatility': 'X'},
#  {'accident_id': '118772.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118772.015',
#   'summary_nr': '118772.01',
#   'event_date': '08/06/2019',
#   'report_id': '0625500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': "Employee'S Face And Forearms Are Burned When Working On Pipe",
#   'fatility': '\xa0'},
#  {'accident_id': '119043.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119043.015',
#   'summary_nr': '119043.01',
#   'event_date': '08/06/2019',
#   'report_id': '0830300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Injured In Flash Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '118951.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118951.015',
#   'summary_nr': '118951.01',
#   'event_date': '08/06/2019',
#   'report_id': '0214500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': "Employee'S Arm Is Impaled By Fire Truck",
#   'fatility': '\xa0'},
#  {'accident_id': '118372.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118372.015',
#   'summary_nr': '118372.01',
#   'event_date': '08/05/2019',
#   'report_id': '0418400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught In Gasoline Flash Fire And Later Dies',
#   'fatility': 'X'},
#  {'accident_id': '123955.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=123955.015',
#   'summary_nr': '123955.01',
#   'event_date': '08/01/2019',
#   'report_id': '0257240',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Burns After Tire Explosion',
#   'fatility': '\xa0'},
#  {'accident_id': '118540.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118540.015',
#   'summary_nr': '118540.01',
#   'event_date': '07/31/2019',
#   'report_id': '0751910',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Explosion While Welding Barrel',
#   'fatility': 'X'},
#  {'accident_id': '122973.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122973.015',
#   'summary_nr': '122973.01',
#   'event_date': '07/31/2019',
#   'report_id': '0626600',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Minor Burns After Explosion And Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '118783.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118783.015',
#   'summary_nr': '118783.01',
#   'event_date': '07/26/2019',
#   'report_id': '0352450',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned In Electric Arc Flash',
#   'fatility': '\xa0'},
#  {'accident_id': '118518.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118518.015',
#   'summary_nr': '118518.01',
#   'event_date': '07/25/2019',
#   'report_id': '0950632',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Burns From Flash Fire While Changing Fuel F',
#   'fatility': '\xa0'},
#  {'accident_id': '118600.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118600.015',
#   'summary_nr': '118600.01',
#   'event_date': '07/24/2019',
#   'report_id': '0751910',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Third Degree Burns After Clothes Catch Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '118764.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118764.015',
#   'summary_nr': '118764.01',
#   'event_date': '07/24/2019',
#   'report_id': '0626300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Burn Injuries From Fuel Explosion',
#   'fatility': '\xa0'}]

# %%
# Accidents Examples
import fcis
import pprint
keys1=[]
desc1=[]
abst = []
client = fcis.FCIS(descriptions=desc1, keywords=keys1)
# print(client._make_accident_details_url(ids=["570341", "116803.015"]))
soup_data = client._load_accident_details_page(ids=["570341", "116803.015", "171061435"])
# soup_data = client._load_accident_details_page(ids=["116803.015"])
# soup_data = client._load_accident_details_page(ids=["570341"])
# soup_data = client._load_accident_details_page(ids=["171061435"])

client._scrape_accident_details(soup_data)

# %%
# Accidents Examples
import fcis
import pprint
keys1=[]
desc1=[]
abst = []
client = fcis.FCIS(descriptions=desc1, keywords=keys1)
# print(client._make_accident_details_url(ids=["570341", "116803.015"]))
# soup_data = client._load_accident_details_page(ids=["570341", "116803.015", "171061435"])
# soup_data = client._load_accident_details_page(ids=["116803.015"])
# soup_data = client._load_accident_details_page(ids=["570341"])
soup_data = client._load_accident_details_page(ids=["171061435"])

client.get_accident_details(ids=["570341"])
# Out:
# {'accident_number': '570341',
#  'report_id': '0522300',
#  'event_date': '08/15/1984',
#  'inspection_url': 'establishment.inspection_detail?id=1667450',
#  'inspection_number': '1667450',
#  'open_date': '08/16/1984',
#  'sic_number': '4741',
#  'establishment_name': 'Mobile Tank Car Services',
#  'detail_description': 'THREE EMPLOYEES WERE CLEANING A RAILROAD TANK CAR CONTAINING RESIDUES OF COAL TAR LIGHT OIL, A FLAMMABLE LIQUID. ONE WAS ON TOP OF THE CAR, THE OTHER TWO WERE INSIDE. THEY WERE USING STEEL SHOVELS AND A NON EXPLOSION-PROOF LIGHT INSIDE THE CAR. THE VAPORS IGNITED, KILLING THE TWO EMPLOYEES INSIDE AND BURNING THE ONE ON TOP. THE OTHER EMPLOYEES WERE INJURED IN THE RESCUE ATTEMPT.',
#  'keywords': ['burn',
#   ' coal tar light oil',
#   ' flammable vapors',
#   ' railroad tank car',
#   ' cleaning',
#   ' explosion'],
#  'Employee': [{'Employee #': '1',
#    'Inspection': '1667450',
#    'Age': '',
#    'Sex': '',
#    'Degree': 'Fatality',
#    'Nature': 'Asphyxia',
#    'Occupation': 'Occupation not reported',
#    '': ''},
#   {'Employee #': '2',
#    'Inspection': '1667450',
#    'Age': '',
#    'Sex': '',
#    'Degree': 'Fatality',
#    'Nature': 'Asphyxia',
#    'Occupation': 'Occupation not reported',
#    '': ''},
#   {'Employee #': '3',
#    'Inspection': '1667450',
#    'Age': '',
#    'Sex': '',
#    'Degree': 'Hospitalized injury',
#    'Nature': 'Other',
#    'Occupation': 'Occupation not reported',
#    '': ''},
#   {'Employee #': '4',
#    'Inspection': '1667450',
#    'Age': '',
#    'Sex': '',
#    'Degree': 'Hospitalized injury',
#    'Nature': 'Other',
#    'Occupation': 'Occupation not reported',
#    '': ''},
#   {'Employee #': '5',
#    'Inspection': '1667450',
#    'Age': '',
#    'Sex': '',
#    'Degree': 'Hospitalized injury',
#    'Nature': 'Other',
#    'Occupation': 'Occupation not reported',
#    '': ''},
#   {'Employee #': '6',
#    'Inspection': '1667450',
#    'Age': '',
#    'Sex': '',
#    'Degree': 'Hospitalized injury',
#    'Nature': 'Other',
#    'Occupation': 'Occupation not reported',
#    '': ''}]}

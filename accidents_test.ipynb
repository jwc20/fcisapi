# %%
from fcis.core import * 
from fcis.accidents import Accidents

# %%
test = Accidents().get_keywords("A")
print(test)
# Out:
# <!DOCTYPE html>
# <html lang="en-us">
# <head>
# <meta charset="utf-8"/>
# <title>Investigation Summary Keywords for the Letter A | Occupational Safety and Health Administration</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <!-- 06/18/2022 -->
# <!-- Site Specific -->
# <meta content="OSHA" name="Agency"/>
# <meta content="NONE" name="Subagency"/>
# <meta content="HTML" name="Doctype"/>
# <meta content="Workplace Safety &amp; Health" name="Subject"/>
# <meta content="TRUE" name="MSSmartTagsPreventParsing"/>
# <meta content="do_not_use_this_for_any_dynamic_pages_01_21_2010" http-equiv="pragma"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <!-- Page Specific -->
# <meta content="workers: general, all" name="Audience"/>
# ...

# %%
from fcis.core import * 
from fcis.accidents import Accidents

# %%
# https://www.osha.gov/pls/imis/AccidentSearch.search
# ?p_logger=1
# &acc_description=boat+Employee
# &acc_Abstract=boat+Employee
# &acc_keyword=water+drown+boat
# &sic=
# &naics=
# &Office=All
# &officetype=All
# &endmonth=06
# &endday=18
# &endyear=2002
# &startmonth=06
# &startday=18
# &startyear=2023
# &InspNr=

# %%
# Accidents Examples
import fcis
desc1= ["boat", "Employee"]
abs1=  ["boat", "Employee"]
keys1 = ["water", "drown", "boat"]
client = fcis.FCIS(descriptions=desc1, abstracts=abs1, keywords=keys1)
# test
# print(client._get_validated_keywords(keys1))
# print(client._load_accidents_search_page())

page = client._load_accidents_search_page()
client._scrape_accidents_search_results(page)

# %%
# Accidents Examples
import fcis
import pprint
desc1= []
keys1 = ['"Quench Tank"']
# keys1 = ['Quench Tank']
client = fcis.FCIS(descriptions=desc1, keywords=keys1)
page = client._load_accidents_search_page()
# page = client._load_accidents_search_page(p_finish=30)
client._scrape_accidents_search_results(page)

# %%
# Accidents Examples
import fcis
import pprint
desc1= ["fire"]
keys1 = []
client = fcis.FCIS(descriptions=desc1, keywords=keys1)
page = client._load_accidents_search_page()
# client._scrape_accidents_search_results(page)
client.get_accidents(p_show=100)
# Out:
# https://www.osha.gov/pls/imis/AccidentSearch.search?acc_description=fire
# https://www.osha.gov/pls/imis/AccidentSearch.search?acc_description=fire&p_show=100
# [{'accident_id': '141079.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=141079.015',
#   'summary_nr': '141079.01',
#   'event_date': '11/11/2021',
#   'report_id': '0111400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Toluene Flash Fire Explosion',
#   'fatility': 'X'},
#  {'accident_id': '139559.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=139559.015',
#   'summary_nr': '139559.01',
#   'event_date': '09/07/2021',
#   'report_id': '0215000',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies Following Building Fire',
#   'fatility': 'X'},
#  {'accident_id': '138653.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138653.015',
#   'summary_nr': '138653.01',
#   'event_date': '08/25/2021',
#   'report_id': '0452110',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Explosion And Fire',
#   'fatility': 'X'},
#  {'accident_id': '138174.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138174.015',
#   'summary_nr': '138174.01',
#   'event_date': '08/16/2021',
#   'report_id': '0950635',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed When Trapped In Fire',
#   'fatility': 'X'},
#  {'accident_id': '138102.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=138102.015',
#   'summary_nr': '138102.01',
#   'event_date': '08/11/2021',
#   'report_id': '0352440',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed Fighting House Fire',
#   'fatility': 'X'},
#  {'accident_id': '137943.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=137943.015',
#   'summary_nr': '137943.01',
#   'event_date': '08/05/2021',
#   'report_id': '0552652',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Trapped And Killed In Fire',
#   'fatility': 'X'},
#  {'accident_id': '136811.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=136811.015',
#   'summary_nr': '136811.01',
#   'event_date': '06/30/2021',
#   'report_id': '0551800',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned In Fire Pit, Later Dies',
#   'fatility': 'X'},
#  {'accident_id': '139968.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=139968.015',
#   'summary_nr': '139968.01',
#   'event_date': '05/12/2021',
#   'report_id': '0150900',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed When Scba Runs Out Of Air During Fire',
#   'fatility': 'X'},
#  {'accident_id': '134464.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134464.015',
#   'summary_nr': '134464.01',
#   'event_date': '03/31/2021',
#   'report_id': '0830600',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed After Being Crushed By Fire Truck Cab',
#   'fatility': 'X'},
#  {'accident_id': '134306.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134306.015',
#   'summary_nr': '134306.01',
#   'event_date': '03/23/2021',
#   'report_id': '0253690',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Building Fire And Collapse',
#   'fatility': 'X'},
#  {'accident_id': '134138.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=134138.015',
#   'summary_nr': '134138.01',
#   'event_date': '03/16/2021',
#   'report_id': '0653510',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Dies After Residual Fluid Fire While Cutting Pipe',
#   'fatility': 'X'},
#  {'accident_id': '130729.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=130729.015',
#   'summary_nr': '130729.01',
#   'event_date': '10/26/2020',
#   'report_id': '0419700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'One Employee Is Killed, Another Is Injured From Fire',
#   'fatility': 'X'},
#  {'accident_id': '131678.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=131678.015',
#   'summary_nr': '131678.01',
#   'event_date': '10/07/2020',
#   'report_id': '0950611',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Fall From Third Floor Fire Escape',
#   'fatility': 'X'},
#  {'accident_id': '129769.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129769.015',
#   'summary_nr': '129769.01',
#   'event_date': '09/21/2020',
#   'report_id': '0453720',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees In Plant Tower Are Engulfed In Fire And Killed',
#   'fatility': 'X'},
#  {'accident_id': '129609.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129609.015',
#   'summary_nr': '129609.01',
#   'event_date': '09/17/2020',
#   'report_id': '0625700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed From Fire And Fall',
#   'fatility': 'X'},
#  {'accident_id': '129180.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129180.015',
#   'summary_nr': '129180.01',
#   'event_date': '09/01/2020',
#   'report_id': '0625400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Front End Loader Fire',
#   'fatility': 'X'},
#  {'accident_id': '129018.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129018.015',
#   'summary_nr': '129018.01',
#   'event_date': '08/26/2020',
#   'report_id': '0552700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Fire Department Captain Dies Of Leukemia',
#   'fatility': 'X'},
#  {'accident_id': '128180.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=128180.015',
#   'summary_nr': '128180.01',
#   'event_date': '07/29/2020',
#   'report_id': '0950621',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Heat Illness While Participating In Fire Dri',
#   'fatility': '\xa0'},
#  {'accident_id': '135643.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=135643.015',
#   'summary_nr': '135643.01',
#   'event_date': '07/17/2020',
#   'report_id': '0950633',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Heat Related Injury Fighting Brush Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '129601.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=129601.015',
#   'summary_nr': '129601.01',
#   'event_date': '07/10/2020',
#   'report_id': '1054112',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Truck Driver Dies After Sustaining Burns In Truck Cab Fire',
#   'fatility': 'X'},
#  {'accident_id': '127876.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=127876.015',
#   'summary_nr': '127876.01',
#   'event_date': '07/09/2020',
#   'report_id': '0627100',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Are Burned After Heater Catches Fire, Explodes',
#   'fatility': '\xa0'},
#  {'accident_id': '127176.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=127176.015',
#   'summary_nr': '127176.01',
#   'event_date': '06/22/2020',
#   'report_id': '0953220',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Using Propane Torch, Catches On Fire And Is Killed',
#   'fatility': 'X'},
#  {'accident_id': '127507.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=127507.015',
#   'summary_nr': '127507.01',
#   'event_date': '06/19/2020',
#   'report_id': '0316300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Fire Incident',
#   'fatility': 'X'},
#  {'accident_id': '125288.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=125288.015',
#   'summary_nr': '125288.01',
#   'event_date': '04/07/2020',
#   'report_id': '0453730',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed By Flash Fire',
#   'fatility': 'X'},
#  {'accident_id': '126350.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=126350.015',
#   'summary_nr': '126350.01',
#   'event_date': '03/27/2020',
#   'report_id': '0253650',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed From Smoke Inhalation From Fire',
#   'fatility': 'X'},
#  {'accident_id': '122470.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122470.015',
#   'summary_nr': '122470.01',
#   'event_date': '01/10/2020',
#   'report_id': '0627700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Automotive Technician Is Burned When Fuel Catches On Fire',
#   'fatility': 'X'},
#  {'accident_id': '126948.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=126948.015',
#   'summary_nr': '126948.01',
#   'event_date': '12/21/2019',
#   'report_id': '0953220',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Attempts To Rescue Residents During Building Fire A',
#   'fatility': 'X'},
#  {'accident_id': '127369.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=127369.015',
#   'summary_nr': '127369.01',
#   'event_date': '12/16/2019',
#   'report_id': '0552652',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Fire',
#   'fatility': 'X'},
#  {'accident_id': '122671.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122671.015',
#   'summary_nr': '122671.01',
#   'event_date': '12/05/2019',
#   'report_id': '0253680',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Responds To Fire Alarm And Is Killed From Heart Att',
#   'fatility': 'X'},
#  {'accident_id': '122161.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122161.015',
#   'summary_nr': '122161.01',
#   'event_date': '11/26/2019',
#   'report_id': '0552652',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught In Flash Fire And Is Killed',
#   'fatility': 'X'},
#  {'accident_id': '124210.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=124210.015',
#   'summary_nr': '124210.01',
#   'event_date': '11/13/2019',
#   'report_id': '0950644',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Trapped In Break Room During Flash Fire And Is K',
#   'fatility': 'X'},
#  {'accident_id': '122056.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122056.015',
#   'summary_nr': '122056.01',
#   'event_date': '10/31/2019',
#   'report_id': '0951510',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Sustain Severe Burns When Caught In Fire, One',
#   'fatility': 'X'},
#  {'accident_id': '124188.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=124188.015',
#   'summary_nr': '124188.01',
#   'event_date': '10/31/2019',
#   'report_id': '0951510',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Sustain Burns During Fire In Recycle Yard, One',
#   'fatility': 'X'},
#  {'accident_id': '120663.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=120663.015',
#   'summary_nr': '120663.01',
#   'event_date': '09/30/2019',
#   'report_id': '0751910',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Burns From Fire, Later Dies',
#   'fatility': 'X'},
#  {'accident_id': '119910.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119910.015',
#   'summary_nr': '119910.01',
#   'event_date': '09/16/2019',
#   'report_id': '0551800',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Fatal Burns When Caught In Petroleum Fire',
#   'fatility': 'X'},
#  {'accident_id': '120682.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=120682.015',
#   'summary_nr': '120682.01',
#   'event_date': '09/01/2019',
#   'report_id': '1055350',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Overcome By Flames From Wildland Fire, Later Die',
#   'fatility': 'X'},
#  {'accident_id': '120228.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=120228.015',
#   'summary_nr': '120228.01',
#   'event_date': '09/01/2019',
#   'report_id': '0936200',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employees Are Caught In Fire On Excursion Boat, One Employee',
#   'fatility': 'X'},
#  {'accident_id': '119642.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119642.015',
#   'summary_nr': '119642.01',
#   'event_date': '08/19/2019',
#   'report_id': '0950624',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Second Degree Burns While Fire Fighting',
#   'fatility': '\xa0'},
#  {'accident_id': '119518.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119518.015',
#   'summary_nr': '119518.01',
#   'event_date': '08/08/2019',
#   'report_id': '0257810',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Are Injured In Overturned Fire Tanker Vehicula',
#   'fatility': '\xa0'},
#  {'accident_id': '119043.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=119043.015',
#   'summary_nr': '119043.01',
#   'event_date': '08/06/2019',
#   'report_id': '0830300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Injured In Flash Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '118951.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118951.015',
#   'summary_nr': '118951.01',
#   'event_date': '08/06/2019',
#   'report_id': '0214500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': "Employee'S Arm Is Impaled By Fire Truck",
#   'fatility': '\xa0'},
#  {'accident_id': '118372.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118372.015',
#   'summary_nr': '118372.01',
#   'event_date': '08/05/2019',
#   'report_id': '0418400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught In Gasoline Flash Fire And Later Dies',
#   'fatility': 'X'},
#  {'accident_id': '122659.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122659.015',
#   'summary_nr': '122659.01',
#   'event_date': '08/03/2019',
#   'report_id': '1054116',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Wild Land Fire Fighter Is Struck By Tree, Sustains Head Trau',
#   'fatility': '\xa0'},
#  {'accident_id': '122973.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122973.015',
#   'summary_nr': '122973.01',
#   'event_date': '07/31/2019',
#   'report_id': '0626600',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Minor Burns After Explosion And Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '118518.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118518.015',
#   'summary_nr': '118518.01',
#   'event_date': '07/25/2019',
#   'report_id': '0950632',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Burns From Flash Fire While Changing Fuel F',
#   'fatility': '\xa0'},
#  {'accident_id': '118384.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118384.015',
#   'summary_nr': '118384.01',
#   'event_date': '07/24/2019',
#   'report_id': '0521100',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned On Body, Arms, And Legs By Fire And Hot T',
#   'fatility': '\xa0'},
#  {'accident_id': '118600.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118600.015',
#   'summary_nr': '118600.01',
#   'event_date': '07/24/2019',
#   'report_id': '0751910',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Third Degree Burns After Clothes Catch Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '122610.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=122610.015',
#   'summary_nr': '122610.01',
#   'event_date': '07/23/2019',
#   'report_id': '0950624',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Rhabdomyolysis During Fire Fighting Training',
#   'fatility': '\xa0'},
#  {'accident_id': '118527.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118527.015',
#   'summary_nr': '118527.01',
#   'event_date': '07/22/2019',
#   'report_id': '0522000',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught By Flash Fire And Is Killed; Five Others',
#   'fatility': 'X'},
#  {'accident_id': '118317.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118317.015',
#   'summary_nr': '118317.01',
#   'event_date': '07/21/2019',
#   'report_id': '0316300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Amputates Thumb In Fire Truck Hose Cover',
#   'fatility': '\xa0'},
#  {'accident_id': '118279.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118279.015',
#   'summary_nr': '118279.01',
#   'event_date': '07/12/2019',
#   'report_id': '0454712',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Burns After Pouring Gas Onto Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '118867.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118867.015',
#   'summary_nr': '118867.01',
#   'event_date': '07/10/2019',
#   'report_id': '0418100',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Flash Fire Burns While Cleaning Residues Off',
#   'fatility': '\xa0'},
#  {'accident_id': '120840.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=120840.015',
#   'summary_nr': '120840.01',
#   'event_date': '07/01/2019',
#   'report_id': '0855610',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Incur Burns From Flash Fire While Cutting Pipe',
#   'fatility': '\xa0'},
#  {'accident_id': '117644.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=117644.015',
#   'summary_nr': '117644.01',
#   'event_date': '06/27/2019',
#   'report_id': '0751910',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned In Flash Fire While Tig Welding',
#   'fatility': '\xa0'},
#  {'accident_id': '117646.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=117646.015',
#   'summary_nr': '117646.01',
#   'event_date': '06/22/2019',
#   'report_id': '0626300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned When Cng Line Explodes And Catches Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '117271.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=117271.015',
#   'summary_nr': '117271.01',
#   'event_date': '06/15/2019',
#   'report_id': '0336000',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Burns Leg When Clothing Catches On Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '118768.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118768.015',
#   'summary_nr': '118768.01',
#   'event_date': '06/13/2019',
#   'report_id': '0552652',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Incurs Multiple Injuries After Hose Is On Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '117158.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=117158.015',
#   'summary_nr': '117158.01',
#   'event_date': '06/12/2019',
#   'report_id': '0855610',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Sustain Burns From Flash Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '116984.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=116984.015',
#   'summary_nr': '116984.01',
#   'event_date': '06/06/2019',
#   'report_id': '0626700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Are Burned In Natural Gas Pipeline Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '116865.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=116865.015',
#   'summary_nr': '116865.01',
#   'event_date': '06/05/2019',
#   'report_id': '0830500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employees Are Burned In Flash Fire While Breaking Piping',
#   'fatility': '\xa0'},
#  {'accident_id': '116627.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=116627.015',
#   'summary_nr': '116627.01',
#   'event_date': '05/21/2019',
#   'report_id': '0522500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught By Flash Fire And Sustains First And Seco',
#   'fatility': '\xa0'},
#  {'accident_id': '116778.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=116778.015',
#   'summary_nr': '116778.01',
#   'event_date': '05/15/2019',
#   'report_id': '0551701',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Burns Hands In House Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '116347.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=116347.015',
#   'summary_nr': '116347.01',
#   'event_date': '05/14/2019',
#   'report_id': '0626000',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Are Caught In Flash Fire And Incur Burns',
#   'fatility': '\xa0'},
#  {'accident_id': '116168.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=116168.015',
#   'summary_nr': '116168.01',
#   'event_date': '05/06/2019',
#   'report_id': '0627500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught In Fire And Sustains Burns',
#   'fatility': '\xa0'},
#  {'accident_id': '116045.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=116045.015',
#   'summary_nr': '116045.01',
#   'event_date': '05/05/2019',
#   'report_id': '0551702',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Firefighter Is Killed In Fire',
#   'fatility': 'X'},
#  {'accident_id': '118172.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=118172.015',
#   'summary_nr': '118172.01',
#   'event_date': '04/24/2019',
#   'report_id': '0213600',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught In Combustible Fire And Sustains Third De',
#   'fatility': 'X'},
#  {'accident_id': '115337.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=115337.015',
#   'summary_nr': '115337.01',
#   'event_date': '04/15/2019',
#   'report_id': '0111400',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': "Employee'S Shirt Catches On Fire At Burning Table, Sustains",
#   'fatility': '\xa0'},
#  {'accident_id': '115803.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=115803.015',
#   'summary_nr': '115803.01',
#   'event_date': '04/10/2019',
#   'report_id': '0854910',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Killed In Natural Gas Fire',
#   'fatility': 'X'},
#  {'accident_id': '115521.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=115521.015',
#   'summary_nr': '115521.01',
#   'event_date': '04/08/2019',
#   'report_id': '0830300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned In Flash Fire At Compressor Station',
#   'fatility': '\xa0'},
#  {'accident_id': '114602.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=114602.015',
#   'summary_nr': '114602.01',
#   'event_date': '03/15/2019',
#   'report_id': '0627100',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Sustain Burns During Fire Flareup At Plant',
#   'fatility': '\xa0'},
#  {'accident_id': '114949.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=114949.015',
#   'summary_nr': '114949.01',
#   'event_date': '03/05/2019',
#   'report_id': '0551702',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'One Employee Is Killed, Three Others Are Injured In Fire',
#   'fatility': 'X'},
#  {'accident_id': '117834.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=117834.015',
#   'summary_nr': '117834.01',
#   'event_date': '02/14/2019',
#   'report_id': '0253410',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Fire Fighters Suffer From Smoke Inhalation, One Sprains',
#   'fatility': '\xa0'},
#  {'accident_id': '113366.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=113366.015',
#   'summary_nr': '113366.01',
#   'event_date': '02/04/2019',
#   'report_id': '0627100',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Severe Burns During Chemical Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '113078.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=113078.015',
#   'summary_nr': '113078.01',
#   'event_date': '01/25/2019',
#   'report_id': '0522000',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Burns During Cryostat Flash Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '115866.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=115866.015',
#   'summary_nr': '115866.01',
#   'event_date': '01/23/2019',
#   'report_id': '0627510',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': "Employee'S Hands Are Burned When Compressor Catches On Fire",
#   'fatility': '\xa0'},
#  {'accident_id': '113011.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=113011.015',
#   'summary_nr': '113011.01',
#   'event_date': '01/16/2019',
#   'report_id': '0728500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Amputates Fingertip By Falling Fire Extinguisher',
#   'fatility': '\xa0'},
#  {'accident_id': '115509.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=115509.015',
#   'summary_nr': '115509.01',
#   'event_date': '01/16/2019',
#   'report_id': '0627100',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Burns Hands And Arms When Building Catches Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '112424.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=112424.015',
#   'summary_nr': '112424.01',
#   'event_date': '01/03/2019',
#   'report_id': '0950631',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Falls While Installing Fire Sprinkler System And  I',
#   'fatility': '\xa0'},
#  {'accident_id': '112148.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=112148.015',
#   'summary_nr': '112148.01',
#   'event_date': '12/19/2018',
#   'report_id': '0830300',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught In Fire After Releasing Flammable Gasses',
#   'fatility': '\xa0'},
#  {'accident_id': '115581.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=115581.015',
#   'summary_nr': '115581.01',
#   'event_date': '12/15/2018',
#   'report_id': '0950644',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Burned By Lance Connection Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '111715.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=111715.015',
#   'summary_nr': '111715.01',
#   'event_date': '12/08/2018',
#   'report_id': '0317500',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Set On Fire When Fuel Line Explodes',
#   'fatility': '\xa0'},
#  {'accident_id': '115201.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=115201.015',
#   'summary_nr': '115201.01',
#   'event_date': '12/05/2018',
#   'report_id': '0352460',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Burns To Body When Engulfed In Fire From F',
#   'fatility': '\xa0'},
#  {'accident_id': '115060.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=115060.015',
#   'summary_nr': '115060.01',
#   'event_date': '11/30/2018',
#   'report_id': '0830600',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Burns When Caught By Flash Fire Of Thc Pro',
#   'fatility': '\xa0'},
#  {'accident_id': '111449.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=111449.015',
#   'summary_nr': '111449.01',
#   'event_date': '11/17/2018',
#   'report_id': '0420600',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Third Degree Burns When Caught By Fire Fro',
#   'fatility': '\xa0'},
#  {'accident_id': '111384.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=111384.015',
#   'summary_nr': '111384.01',
#   'event_date': '11/17/2018',
#   'report_id': '0420600',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Caught In Food Truck Fire Flareup And Sustains M',
#   'fatility': '\xa0'},
#  {'accident_id': '110901.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=110901.015',
#   'summary_nr': '110901.01',
#   'event_date': '11/11/2018',
#   'report_id': '0521700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Is Injured In Tank Demolition Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '117133.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=117133.015',
#   'summary_nr': '117133.01',
#   'event_date': '11/08/2018',
#   'report_id': '1054114',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Suffers Burns By Warming Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '110690.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=110690.015',
#   'summary_nr': '110690.01',
#   'event_date': '10/31/2018',
#   'report_id': '0626700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Multiple Burns When Fire Flares Up In Barr',
#   'fatility': '\xa0'},
#  {'accident_id': '110895.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=110895.015',
#   'summary_nr': '110895.01',
#   'event_date': '10/30/2018',
#   'report_id': '0625700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Multiple Burns When Caught By Flash Fire W',
#   'fatility': '\xa0'},
#  {'accident_id': '110527.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=110527.015',
#   'summary_nr': '110527.01',
#   'event_date': '10/26/2018',
#   'report_id': '0522000',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Three Employees Sustain Multiple Burns During Flash Fire Whe',
#   'fatility': '\xa0'},
#  {'accident_id': '110322.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=110322.015',
#   'summary_nr': '110322.01',
#   'event_date': '10/17/2018',
#   'report_id': '0950411',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Collapsed And Died After Fire Drill',
#   'fatility': 'X'},
#  {'accident_id': '111340.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=111340.015',
#   'summary_nr': '111340.01',
#   'event_date': '10/16/2018',
#   'report_id': '0950621',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Catches Sleeve On Fire And Sustains Several Burns',
#   'fatility': '\xa0'},
#  {'accident_id': '110625.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=110625.015',
#   'summary_nr': '110625.01',
#   'event_date': '10/14/2018',
#   'report_id': '0950621',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Burns When Caught In Propane Tank Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '110170.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=110170.015',
#   'summary_nr': '110170.01',
#   'event_date': '10/11/2018',
#   'report_id': '0418200',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Burns Hands And Arms In Fire Started During Floor F',
#   'fatility': '\xa0'},
#  {'accident_id': '110192.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=110192.015',
#   'summary_nr': '110192.01',
#   'event_date': '10/11/2018',
#   'report_id': '0111100',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Two Employees Are Burned In Kitchen Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '110159.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=110159.015',
#   'summary_nr': '110159.01',
#   'event_date': '10/10/2018',
#   'report_id': '0728900',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Burns Face And Head When Caught By Fire Ball From R',
#   'fatility': '\xa0'},
#  {'accident_id': '114269.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=114269.015',
#   'summary_nr': '114269.01',
#   'event_date': '10/05/2018',
#   'report_id': '0950635',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Three Employees Suffer Burns From Oven Fire',
#   'fatility': '\xa0'},
#  {'accident_id': '109773.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=109773.015',
#   'summary_nr': '109773.01',
#   'event_date': '09/25/2018',
#   'report_id': '0626700',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Burns From Flash Fire At Oil And Gas Well',
#   'fatility': '\xa0'},
#  {'accident_id': '111504.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=111504.015',
#   'summary_nr': '111504.01',
#   'event_date': '09/10/2018',
#   'report_id': '0950621',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Receives Heat Injury While Installing Fire Sprinkle',
#   'fatility': '\xa0'},
#  {'accident_id': '113100.015',
#   'summary_url': 'https://www.osha.gov/pls/imis/accidentsearch.accident_detail?id=113100.015',
#   'summary_nr': '113100.01',
#   'event_date': '08/19/2018',
#   'report_id': '0950621',
#   'fatality': None,
#   'sic_url': None,
#   'sic_number': None,
#   'event_description': 'Employee Sustains Burns While Fighting Fire',
#   'fatility': '\xa0'}]

# %%
# Accidents Examples
import fcis
import pprint
keys1=[]
desc1=[]
abst = []
client = fcis.FCIS(descriptions=desc1, keywords=keys1)
# print(client._make_accident_details_url(ids=["570341", "116803.015"]))
soup_data = client._load_accident_details_page(ids=["570341", "116803.015", "171061435"])
# soup_data = client._load_accident_details_page(ids=["116803.015"])
# soup_data = client._load_accident_details_page(ids=["570341"])
# soup_data = client._load_accident_details_page(ids=["171061435"])

client._scrape_accident_details(soup_data)

# %%
# Accidents Examples
import fcis
import pprint
keys1=[]
desc1=[]
abst = []
client = fcis.FCIS(descriptions=desc1, keywords=keys1)
# print(client._make_accident_details_url(ids=["570341", "116803.015"]))
# soup_data = client._load_accident_details_page(ids=["570341", "116803.015", "171061435"])
# soup_data = client._load_accident_details_page(ids=["116803.015"])
# soup_data = client._load_accident_details_page(ids=["570341"])
soup_data = client._load_accident_details_page(ids=["171061435"])

client.get_accident_details(ids=["171061435"])
# Out:
# {'accident_number': '171061435',
#  'report_id': '0854910',
#  'event_date': '09/19/2001',
#  'inspection_url': 'establishment.inspection_detail?id=304411838',
#  'inspection_number': '304411838',
#  'open_date': '09/20/2001',
#  'sic_number': '1794',
#  'establishment_name': 'Giles & Mcfarland Excavating',
#  'detail_description': "On September 19, 2001, Employee #1 was rolling/compacting backfill to join two roads together that were under construction. Employee #1 was rolling/compacting the west edge of the roadway when the vehicle's front left tire went off the embankment causing the compactor to roll down the embankment. Employee #1 was crushed and killed.",
#  'keywords': ['embankment',
#   ' roller--const equip',
#   ' roll-over',
#   ' rops',
#   ' crushed'],
#  'Employee': [{'Employee #': '1',
#    'Inspection': '304411838',
#    'Age': '',
#    'Sex': '',
#    'Degree': 'Fatality',
#    'Nature': 'Other'}]}
